# %%
import numpy as np

# %% [raw]
# import pandas as pd

# %%
import pandas as pd

# %%
from sklearn import datasets

# %%
data = pd.read_csv('brain_size.csv')

# %%
data
# Out:
#    ;"Gender";"FSIQ";"VIQ";"PIQ";"Weight";"Height";"MRI_Count"
# 0          1;"Female";133;132;124;"118";"64.5";816932
# 1             2;"Male";140;150;124;".";"72.5";1001121
# 2           3;"Male";139;123;150;"143";"73.3";1038437
# 3            4;"Male";133;129;128;"172";"68.8";965353
# 4          5;"Female";137;132;134;"147";"65.0";951545
# 5            6;"Female";99;90;110;"146";"69.0";928799
# 6          7;"Female";138;136;131;"138";"64.5";991305
# 7             8;"Female";92;90;98;"175";"66.0";854258
# 8               9;"Male";89;93;84;"134";"66.3";904858
# 9           10;"Male";133;114;147;"172";"68.8";955466
# 10        11;"Female";132;129;124;"118";"64.5";833868
# 11         12;"Male";141;150;128;"151";"70.0";1079549
# 12          13;"Male";135;129;124;"155";"69.0";924059
# 13        14;"Female";140;120;147;"155";"70.5";856472
# 14          15;"Female";96;100;90;"146";"66.0";878897
# 15           16;"Female";83;71;96;"135";"68.0";865363
# 16        17;"Female";132;132;120;"127";"68.5";852244
# 17           18;"Male";100;96;102;"178";"73.5";945088
# 18         19;"Female";101;112;84;"136";"66.3";808020
# 19             20;"Male";80;77;86;"180";"70.0";889083
# 20                  21;"Male";83;83;86;".";".";892420
# 21            22;"Male";97;107;84;"186";"76.5";905940
# 22        23;"Female";135;129;134;"122";"62.0";790619
# 23          24;"Male";139;145;128;"132";"68.0";955003
# 24          25;"Female";91;86;102;"114";"63.0";831772
# 25          26;"Male";141;145;131;"171";"72.0";935494
# 26           27;"Female";85;90;84;"140";"68.0";798612
# 27          28;"Male";103;96;110;"187";"77.0";1062462
# 28           29;"Female";77;83;72;"106";"63.0";793549
# 29        30;"Female";130;126;124;"159";"66.5";866662
# 30        31;"Female";133;126;132;"127";"62.5";857782
# 31          32;"Male";144;145;137;"191";"67.0";949589
# 32           33;"Male";103;96;110;"192";"75.5";997925
# 33             34;"Male";90;96;86;"181";"69.0";879987
# 34           35;"Female";83;90;81;"143";"66.5";834344
# 35        36;"Female";133;129;128;"153";"66.5";948066
# 36          37;"Male";140;150;124;"144";"70.5";949395
# 37           38;"Female";88;86;94;"139";"64.5";893983
# 38             39;"Male";81;90;74;"148";"74.0";930016
# 39             40;"Male";89;91;89;"179";"75.5";935863

# %%
data = pd.read_csv('brain_size.csv',sep=";",decimal='.')

# %%
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0            1  Female   133  132  124    118   64.5     816932
# 1            2    Male   140  150  124      .   72.5    1001121
# 2            3    Male   139  123  150    143   73.3    1038437
# 3            4    Male   133  129  128    172   68.8     965353
# 4            5  Female   137  132  134    147   65.0     951545
# 5            6  Female    99   90  110    146   69.0     928799
# 6            7  Female   138  136  131    138   64.5     991305
# 7            8  Female    92   90   98    175   66.0     854258
# 8            9    Male    89   93   84    134   66.3     904858
# 9           10    Male   133  114  147    172   68.8     955466
# 10          11  Female   132  129  124    118   64.5     833868
# 11          12    Male   141  150  128    151   70.0    1079549
# 12          13    Male   135  129  124    155   69.0     924059
# 13          14  Female   140  120  147    155   70.5     856472
# 14          15  Female    96  100   90    146   66.0     878897
# 15          16  Female    83   71   96    135   68.0     865363
# 16          17  Female   132  132  120    127   68.5     852244
# 17          18    Male   100   96  102    178   73.5     945088
# 18          19  Female   101  112   84    136   66.3     808020
# 19          20    Male    80   77   86    180   70.0     889083
# 20          21    Male    83   83   86      .      .     892420
# 21          22    Male    97  107   84    186   76.5     905940
# 22          23  Female   135  129  134    122   62.0     790619
# 23          24    Male   139  145  128    132   68.0     955003
# 24          25  Female    91   86  102    114   63.0     831772
# 25          26    Male   141  145  131    171   72.0     935494
# 26          27  Female    85   90   84    140   68.0     798612
# 27          28    Male   103   96  110    187   77.0    1062462
# 28          29  Female    77   83   72    106   63.0     793549
# 29          30  Female   130  126  124    159   66.5     866662
# 30          31  Female   133  126  132    127   62.5     857782
# 31          32    Male   144  145  137    191   67.0     949589
# 32          33    Male   103   96  110    192   75.5     997925
# 33          34    Male    90   96   86    181   69.0     879987
# 34          35  Female    83   90   81    143   66.5     834344
# 35          36  Female   133  129  128    153   66.5     948066
# 36          37    Male   140  150  124    144   70.5     949395
# 37          38  Female    88   86   94    139   64.5     893983
# 38          39    Male    81   90   74    148   74.0     930016
# 39          40    Male    89   91   89    179   75.5     935863

# %%
"1";"Female";133;132;124;"118";"64.5";816932
# Out:
# 816932

# %%
"2";"Male";140;150;124;".";"72.5";1001121
# Out:
# 1001121

# %%
"3";"Male";139;123;150;"143";"73.3";1038437
# Out:
# 1038437

# %%
"4";"Male";133;129;128;"172";"68.8";965353
# Out:
# 965353

# %%
"5";"Female";137;132;134;"147";"65.0";951545
# Out:
# 951545

# %%
data.head(2)
# Out:
#    Unnamed: 0  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0           1  Female   133  132  124    118   64.5     816932
# 1           2    Male   140  150  124      .   72.5    1001121

# %%
data.tail(2)
# Out:
#     Unnamed: 0 Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 38          39   Male    81   90   74    148   74.0     930016
# 39          40   Male    89   91   89    179   75.5     935863

# %%
data.shape
# Out:
# (40, 8)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0        FSIQ         VIQ        PIQ     MRI_Count
# count   40.000000   40.000000   40.000000   40.00000  4.000000e+01
# mean    20.500000  113.450000  112.350000  111.02500  9.087550e+05
# std     11.690452   24.082071   23.616107   22.47105  7.228205e+04
# min      1.000000   77.000000   71.000000   72.00000  7.906190e+05
# 25%     10.750000   89.750000   90.000000   88.25000  8.559185e+05
# 50%     20.500000  116.500000  113.000000  115.00000  9.053990e+05
# 75%     30.250000  135.500000  129.750000  128.00000  9.500780e+05
# max     40.000000  144.000000  150.000000  150.00000  1.079549e+06

# %%
print(data['Gender'])
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %%
data[data['Gender'] == 'Female']['VIQ'].mean()
# Out:
# 109.45

# %%
groupby_gender = data.groupby('Gender')

# %%
groupby_sex = data.groupby('Gender')

# %%
groupby_sex.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45   862654.6
# Male         21.35  115.0  115.25  111.60   954855.4

# %%
groupby_sex.boxplot()
# Out:
# Female         AxesSubplot(0.1,0.15;0.363636x0.75)
# Male      AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
for element, value in groupby_sex['VIQ']:
    print(element,value.mean())
# Out:
# Female 109.45
# Male 115.25

# %%
from pandas.tools import plotting
plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# C:\Users\Ania\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BB02B38>]],
#       dtype=object)

# %%
plotting.scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# C:\Users\Ania\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BDFDF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BB0BCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BB06CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BE79748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BEB0C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BEB0CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BF12F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BF49F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BF90518>]],
#       dtype=object)

# %%
from scipy import stats
